# %% [markdown]
# 📜 1. Librerías
#
# Importamos las funciones de PySpark para transformar datos.
# * `from pyspark.sql.functions import *`

# %%
from pyspark.sql.functions import *

# %% [markdown]
#  2. Arquitectura:
#
#  Creación de Catálogo, Esquemas y Volúmenes
# 1. Crear el catálogo `Lab_1`.
# 2. Crear los esquemas `bronze`, `silver` y `gold` dentro del catálogo.
# 3. Crear el volumen `bronze_vol` dentro del esquema `bronze`.
# 4. Crear la carpeta `files` dentro del volumen.
# 5. Cargar manualmente los archivos `patients.csv`, `location.csv` y `appointments.txt` en la carpeta.

# %%
# %sql
-- empezar de cero
-- drop catalog if exists lab_1 cascade;

# %%
# %sql
create catalog if not exists lab_1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create schema if not exists lab_1.bronze;
create schema if not exists lab_1.silver;
create schema if not exists lab_1.gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create volume if not exists lab_1.bronze.bronze_vol;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
import os
os.makedirs("/Volumes/lab_1/bronze/bronze_vol/files", exist_ok=True)

# %% [markdown]
# 🥉 3. Esquema Bronze: Creación de Tablas
#
#
# Tomamos los datos de los archivos y los guardamos como tablas en el esquema `bronze`.
# 1. Crear la tabla `patients` usando los datos de `patients.csv` *(Opción 1: Usando SQL)*.
# 2. Crear la tabla `patients` usando los datos de `patients.csv` *(Opción 2: Usando PySpark)*.
# 3. Crear la tabla `location` usando los datos de `location.csv` *(Usando PySpark)*.
# 4. Crear la tabla `appointments` usando los datos de `appointments.csv` *(Usando PySpark)*.

# %%
# %sql
create or replace table lab_1.bronze.patients as (
  select * from read_files(
    '/Volumes/lab_1/bronze/bronze_vol/files/patients.csv',
    format => 'csv',
    header => true,
    inferschema => false,
    delimiter => ';'
  )
);

select * from lab_1.bronze.patients limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>locationId</th><th>_rescued_data</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>1</td><td>null</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2</td><td>null</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>3</td><td>null</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>4</td><td>null</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>5</td><td>null</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>6</td><td>null</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>7</td><td>null</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>8</td><td>null</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>9</td><td>null</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>2</td><td>null</td></tr></tbody></table></div>

# %%
df_patients = spark\
    .read\
    .format("csv")\
    .option("header", "true")\
    .option("inferSchema", "false")\
    .option("delimiter", ";")\
    .load("/Volumes/lab_1/bronze/bronze_vol/files/patients.csv")

df_patients\
.write\
.mode("overwrite")\
.saveAsTable("lab_1.bronze.patients")

display(df_patients.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>locationId</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>1</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>3</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>4</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>5</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>6</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>7</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>8</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>9</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>2</td></tr></tbody></table></div>

# %%
df_location = spark.read\
    .format("csv")\
    .option("header", "true")\
    .option("inferSchema", "false")\
    .option("delimiter", ",")\
    .load("/Volumes/lab_1/bronze/bronze_vol/files/location.csv")

df_location\
    .write\
    .mode("overwrite")\
    .saveAsTable("lab_1.bronze.location")

display(df_location.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>state</th><th>county</th><th>Id</th></tr></thead><tbody><tr><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>1</td></tr><tr><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>2</td></tr><tr><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>3</td></tr><tr><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td></tr><tr><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>5</td></tr><tr><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td><td>6</td></tr><tr><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td><td>7</td></tr><tr><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>8</td></tr><tr><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>9</td></tr><tr><td>Medfield</td><td>Massachusetts</td><td>Norfolk County</td><td>10</td></tr></tbody></table></div>

# %%
df_appointments = spark\
    .read\
    .format("csv")\
    .option("header", "true")\
    .option("inferSchema", "false")\
    .option("delimiter", "\t")\
    .load("/Volumes/lab_1/bronze/bronze_vol/files/appointments.txt")

df_appointments\
    .write\
    .mode("overwrite")\
    .saveAsTable("lab_1.bronze.appointments")

display(df_appointments.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>appointment_date</th><th>patientId</th><th>insurance</th><th>appointment_cost</th></tr></thead><tbody><tr><td>74d8e8e3-340d-5dec-6471-44ccf5efa12c</td><td>2016-09-18T08:15:41Z</td><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>UnitedHealthcare</td><td>347.38</td></tr><tr><td>7adc915c-192a-d800-df52-783ec9de926c</td><td>2021-11-24T21:51:06Z</td><td>7adc915c-192a-d800-96e1-776559c15965</td><td>UnitedHealthcare</td><td>1068.55</td></tr><tr><td>2df76ddc-65c1-4909-d212-f53a70801d60</td><td>2012-02-13T16:34:17Z</td><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>70c2211c-b7b7-d0fc-d12b-b97418f5b16a</td><td>2013-12-22T01:50:04Z</td><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>Blue Cross Blue Shield</td><td>85.55</td></tr><tr><td>70c2211c-b7b7-d0fc-bb48-33d3625de710</td><td>2014-01-19T14:50:04Z</td><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>Blue Cross Blue Shield</td><td>516.95</td></tr><tr><td>43f41797-8919-badf-8401-4cd2d879de24</td><td>2013-02-17T10:09:37Z</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>136.8</td></tr><tr><td>43f41797-8919-badf-f449-9f68f3388ce8</td><td>2016-03-06T10:09:37Z</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>272.8</td></tr><tr><td>2df76ddc-65c1-4909-4055-d67310fd7323</td><td>2016-02-29T16:34:17Z</td><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>74d8e8e3-340d-5dec-c0f1-195d70919484</td><td>2016-10-23T08:15:41Z</td><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>43f41797-8919-badf-159f-a97a7a7bb3ac</td><td>2017-03-12T10:09:37Z</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>704.2</td></tr></tbody></table></div>

# %% [markdown]
# 🥈 4. Esquema Silver: Transformación de Tipos de Datos y Nombres
#
#
# Tomamos las tablas del esquema `bronze`, aseguramos que los tipos de datos sean correctos, igualamos los nombres de las columnas de cruce y las guardamos en el esquema `silver`.
#
# 1. **Tabla `patients`:**
#    * `birthdate` (pasa a tipo Fecha) y `locationId` (pasa a tipo Entero).
#    * `Id` (pasa a llamarse `patientId`).
#    * Guardamos la tabla en el esquema `silver`.
# 2. **Tabla `appointments`:**
#    * `appointment_date` (pasa a tipo Fecha) y `appointment_cost` (pasa a tipo Decimal).
#    * `Id` (pasa a llamarse `appointmentId`).
#    * Guardamos la tabla en el esquema `silver`.
# 3. **Tabla `location`:**
#    * `Id` (pasa a tipo Entero).
#    * `Id` (pasa a llamarse `locationId`).
#    * Guardamos la tabla en el esquema `silver`.

# %%
df_patients_silver = spark.read.table("lab_1.bronze.patients")\
    .withColumn("birthdate", to_date(col("birthdate"), "yyyy-MM-dd"))\
    .withColumn("locationId", col("locationId").cast("integer"))\
    .withColumnRenamed("Id", "patientId")

df_patients_silver.write\
    .mode("overwrite")\
    .saveAsTable("lab_1.silver.patients")

display(df_patients_silver.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>locationId</th><th>_rescued_data</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>1</td><td>null</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2</td><td>null</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>3</td><td>null</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>4</td><td>null</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>5</td><td>null</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>6</td><td>null</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>7</td><td>null</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>8</td><td>null</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>9</td><td>null</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>2</td><td>null</td></tr></tbody></table></div>

# %%
df_appointments_silver = spark.read.table("lab_1.bronze.appointments")\
    .withColumn("appointment_date", to_date("appointment_date", "yyyy-MM-dd'T'HH:mm:ss'Z'"))\
    .withColumn("appointment_cost", col("appointment_cost").cast("double"))\
    .withColumnRenamed("Id", "appointmentId")

df_appointments_silver.write\
    .mode("overwrite")\
    .saveAsTable("lab_1.silver.appointments")

display(df_appointments_silver.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointmentId</th><th>appointment_date</th><th>patientId</th><th>insurance</th><th>appointment_cost</th></tr></thead><tbody><tr><td>74d8e8e3-340d-5dec-6471-44ccf5efa12c</td><td>2016-09-18</td><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>UnitedHealthcare</td><td>347.38</td></tr><tr><td>7adc915c-192a-d800-df52-783ec9de926c</td><td>2021-11-24</td><td>7adc915c-192a-d800-96e1-776559c15965</td><td>UnitedHealthcare</td><td>1068.55</td></tr><tr><td>2df76ddc-65c1-4909-d212-f53a70801d60</td><td>2012-02-13</td><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>70c2211c-b7b7-d0fc-d12b-b97418f5b16a</td><td>2013-12-22</td><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>Blue Cross Blue Shield</td><td>85.55</td></tr><tr><td>70c2211c-b7b7-d0fc-bb48-33d3625de710</td><td>2014-01-19</td><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>Blue Cross Blue Shield</td><td>516.95</td></tr><tr><td>43f41797-8919-badf-8401-4cd2d879de24</td><td>2013-02-17</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>136.8</td></tr><tr><td>43f41797-8919-badf-f449-9f68f3388ce8</td><td>2016-03-06</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>272.8</td></tr><tr><td>2df76ddc-65c1-4909-4055-d67310fd7323</td><td>2016-02-29</td><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>74d8e8e3-340d-5dec-c0f1-195d70919484</td><td>2016-10-23</td><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>UnitedHealthcare</td><td>272.8</td></tr><tr><td>43f41797-8919-badf-159f-a97a7a7bb3ac</td><td>2017-03-12</td><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>Blue Cross Blue Shield</td><td>704.2</td></tr></tbody></table></div>

# %%
df_location_silver = spark.read.table("lab_1.bronze.location")\
    .withColumn("Id", col("Id").cast("integer"))\
    .withColumnRenamed("Id", "locationId")

df_location_silver.write\
    .mode("overwrite")\
    .saveAsTable("lab_1.silver.location")

display(df_location_silver.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>state</th><th>county</th><th>locationId</th></tr></thead><tbody><tr><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>1</td></tr><tr><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>2</td></tr><tr><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>3</td></tr><tr><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td></tr><tr><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>5</td></tr><tr><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td><td>6</td></tr><tr><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td><td>7</td></tr><tr><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>8</td></tr><tr><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>9</td></tr><tr><td>Medfield</td><td>Massachusetts</td><td>Norfolk County</td><td>10</td></tr></tbody></table></div>

# %% [markdown]
# 🥈 5. Esquema Silver: Cruce de Tablas (Join)
#
#
# 1. Unimos pacientes (`patients`) con sus consultas médicas (`appointments`) y su ubicación (`location`).
# *(Nota: Seleccionamos los campos en común una sola vez para evitar columnas duplicadas).*

# %%
df_join = spark.read.table("lab_1.silver.patients").alias("p")\
    .join(spark.read.table("lab_1.silver.appointments").alias("a"), col("p.patientId") == col("a.patientId"), "left")\
    .join(spark.read.table("lab_1.silver.location").alias("l"), col("p.locationId") == col("l.locationId"), "left")\
    .select("p.patientId", "p.birthdate", "p.SSN", "p.first_name", "p.last_name", "p.sex",
            "a.appointmentId", "a.appointment_date", "a.insurance", "a.appointment_cost",
            "l.locationId", "l.city", "l.state", "l.county"
            )

display(df_join.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-b66d-ac77af467987</td><td>2026-01-05</td><td>Medicare</td><td>278.58</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-9d22-2f733e9589db</td><td>2025-06-02</td><td>UnitedHealthcare</td><td>85.55</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-b24c-0f5e6209918a</td><td>2025-09-28</td><td>UnitedHealthcare</td><td>3105.35</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-24aa-4507859fc9f8</td><td>2025-11-05</td><td>UnitedHealthcare</td><td>3105.35</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-43f2-39ff185196c9</td><td>2026-02-08</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>d2b9de8c-6a73-8e6a-3c49-0e0fe68584f7</td><td>1963-06-21</td><td>Humana</td><td>211.38</td><td>6</td><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>37a1f506-1a20-57ff-f921-41b872dabfb6</td><td>2026-01-13</td><td>Cigna Health</td><td>1130.48</td><td>7</td><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-52b6-2029fe435703</td><td>2025-08-27</td><td>Anthem</td><td>934.16</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-9b22-4c200c5f6db2</td><td>2025-06-01</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>7e186c87-e130-61e6-b562-206562a77cc6</td><td>2023-11-02</td><td>Anthem</td><td>3536.75</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td></tr></tbody></table></div>

# %% [markdown]
# 🥈 6. Esquema Silver: Agregar Nuevos Campos
# Agregamos nuevos campos a la tabla cruzada:
# * **`age`**: Calculamos la edad actual del paciente basándonos en su fecha de nacimiento (`birthdate`) y la fecha actual.
# * **`appointment_year`**: Extraemos el año de la fecha de consulta (`appointment_date`).
# * **`appointment_cost_tier`**: Categorizamos el costo de la consulta médica (`appointment_cost`) en:
#   * 🟢 **low:** menor a $500
#   * 🟡 **medium:** entre $500 y $3000
#   * 🟠 **high:** entre $3000 y $20000
#   * 🔴 **critical:** mayor a $20000

# %%
df_age = df_join\
    .withColumn("age", floor(months_between(current_date(), col("birthdate"))/12).cast("integer"))

display(df_age.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th><th>age</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-b66d-ac77af467987</td><td>2026-01-05</td><td>Medicare</td><td>278.58</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-9d22-2f733e9589db</td><td>2025-06-02</td><td>UnitedHealthcare</td><td>85.55</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-b24c-0f5e6209918a</td><td>2025-09-28</td><td>UnitedHealthcare</td><td>3105.35</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>9</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-24aa-4507859fc9f8</td><td>2025-11-05</td><td>UnitedHealthcare</td><td>3105.35</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-43f2-39ff185196c9</td><td>2026-02-08</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>17</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>d2b9de8c-6a73-8e6a-3c49-0e0fe68584f7</td><td>1963-06-21</td><td>Humana</td><td>211.38</td><td>6</td><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td><td>87</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>37a1f506-1a20-57ff-f921-41b872dabfb6</td><td>2026-01-13</td><td>Cigna Health</td><td>1130.48</td><td>7</td><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td><td>16</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-52b6-2029fe435703</td><td>2025-08-27</td><td>Anthem</td><td>934.16</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>19</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-9b22-4c200c5f6db2</td><td>2025-06-01</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>7e186c87-e130-61e6-b562-206562a77cc6</td><td>2023-11-02</td><td>Anthem</td><td>3536.75</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>33</td></tr></tbody></table></div>

# %%
df_year = df_age\
    .withColumn("year", date_format("appointment_date", "yyyy").cast("integer"))

display(df_year.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th><th>age</th><th>year</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-b66d-ac77af467987</td><td>2026-01-05</td><td>Medicare</td><td>278.58</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td><td>2026</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-9d22-2f733e9589db</td><td>2025-06-02</td><td>UnitedHealthcare</td><td>85.55</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2025</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-b24c-0f5e6209918a</td><td>2025-09-28</td><td>UnitedHealthcare</td><td>3105.35</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>9</td><td>2025</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-24aa-4507859fc9f8</td><td>2025-11-05</td><td>UnitedHealthcare</td><td>3105.35</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td><td>2025</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-43f2-39ff185196c9</td><td>2026-02-08</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>17</td><td>2026</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>d2b9de8c-6a73-8e6a-3c49-0e0fe68584f7</td><td>1963-06-21</td><td>Humana</td><td>211.38</td><td>6</td><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td><td>87</td><td>1963</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>37a1f506-1a20-57ff-f921-41b872dabfb6</td><td>2026-01-13</td><td>Cigna Health</td><td>1130.48</td><td>7</td><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td><td>16</td><td>2026</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-52b6-2029fe435703</td><td>2025-08-27</td><td>Anthem</td><td>934.16</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>19</td><td>2025</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-9b22-4c200c5f6db2</td><td>2025-06-01</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td><td>2025</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>7e186c87-e130-61e6-b562-206562a77cc6</td><td>2023-11-02</td><td>Anthem</td><td>3536.75</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>33</td><td>2023</td></tr></tbody></table></div>

# %%
df_tier = df_year\
    .withColumn("appointment_cost_tier",
                when(col("appointment_cost") <= 500, "low")
                .when(col("appointment_cost") <= 3000, "medium")
                .when(col("appointment_cost") <= 20000, "high")
                .otherwise("critical")
                )

display(df_tier.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th><th>age</th><th>year</th><th>appointment_cost_tier</th></tr></thead><tbody><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-b66d-ac77af467987</td><td>2026-01-05</td><td>Medicare</td><td>278.58</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td><td>2026</td><td>low</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-9d22-2f733e9589db</td><td>2025-06-02</td><td>UnitedHealthcare</td><td>85.55</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2025</td><td>low</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-b24c-0f5e6209918a</td><td>2025-09-28</td><td>UnitedHealthcare</td><td>3105.35</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>9</td><td>2025</td><td>high</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-24aa-4507859fc9f8</td><td>2025-11-05</td><td>UnitedHealthcare</td><td>3105.35</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td><td>2025</td><td>high</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-43f2-39ff185196c9</td><td>2026-02-08</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>17</td><td>2026</td><td>medium</td></tr><tr><td>d2b9de8c-6a73-8e6a-f4b2-ee5cc4d0ea73</td><td>1938-07-29</td><td>999-67-4050</td><td>Billy698</td><td>Gorczany269</td><td>M</td><td>d2b9de8c-6a73-8e6a-3c49-0e0fe68584f7</td><td>1963-06-21</td><td>Humana</td><td>211.38</td><td>6</td><td>Auburn</td><td>Massachusetts</td><td>Worcester County</td><td>87</td><td>1963</td><td>low</td></tr><tr><td>37a1f506-1a20-57ff-64ba-9d3015054d47</td><td>2009-12-01</td><td>999-98-2671</td><td>Carl856</td><td>Smith67</td><td>M</td><td>37a1f506-1a20-57ff-f921-41b872dabfb6</td><td>2026-01-13</td><td>Cigna Health</td><td>1130.48</td><td>7</td><td>Hamilton</td><td>Massachusetts</td><td>Essex County</td><td>16</td><td>2026</td><td>medium</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-52b6-2029fe435703</td><td>2025-08-27</td><td>Anthem</td><td>934.16</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>19</td><td>2025</td><td>medium</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-9b22-4c200c5f6db2</td><td>2025-06-01</td><td>Blue Cross Blue Shield</td><td>704.2</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td><td>2025</td><td>medium</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>7e186c87-e130-61e6-b562-206562a77cc6</td><td>2023-11-02</td><td>Anthem</td><td>3536.75</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>33</td><td>2023</td><td>high</td></tr></tbody></table></div>

# %% [markdown]
# 🥈 7. Esquema Silver: Limpieza y Calidad de Datos
# 1. **Filtrado de errores:** Eliminamos filas que cumplan alguna de estas condiciones:
#    * `patientId` nulo.
#    * `appointmentId` nulo.
#    * Identificación `SSN` nula.
#    * Edad (`age`) negativa.
#    * Costo de consulta (`appointment_cost`) negativo.
# 2. **Eliminamos consultas médicas duplicadas** (filas donde `patientId`, `appointmentId` y `appointment_date` se repitan al mismo tiempo).
# 3. Guardamos la tabla limpia como `consolidated` en el esquema `silver`.
# 4. Guardamos los datos descartados en una tabla llamada `rejected` para futuras auditorías.

# %%
df_limpio = df_tier\
    .filter(~(col("patientId").isNull() | col("appointmentId").isNull() | col("SSN").isNull() | (col("age") < 0) | (col("appointment_cost") < 0)))\
    .dropDuplicates(["patientId", "appointmentId", "appointment_date"])

df_limpio.write\
    .mode("overwrite")\
    .saveAsTable("lab_1.silver.consolidated")

df_rejectado = df_tier\
    .filter((col("patientId").isNull() | col("appointmentId").isNull() | col("SSN").isNull() | (col("age") < 0) | (col("appointment_cost") < 0)))

df_rejectado.write\
    .mode("overwrite")\
    .saveAsTable("lab_1.silver.rejected")


display(df_limpio.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th><th>age</th><th>year</th><th>appointment_cost_tier</th></tr></thead><tbody><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-980b-4dac6f7f76ba</td><td>2017-03-13</td><td>UnitedHealthcare</td><td>3536.75</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2017</td><td>high</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-6058-643a3e3427b9</td><td>2022-05-04</td><td>UnitedHealthcare</td><td>1032.5</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td><td>2022</td><td>medium</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-a3fd-1ced8edfd5f2</td><td>2019-03-18</td><td>UnitedHealthcare</td><td>704.2</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2019</td><td>medium</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-8b1a-21066057eab9</td><td>2019-03-25</td><td>UnitedHealthcare</td><td>3968.15</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2019</td><td>high</td></tr><tr><td>2df76ddc-65c1-4909-174b-5ca458ddba02</td><td>2009-03-09</td><td>999-39-8239</td><td>Tristan353</td><td>Balistreri607</td><td>M</td><td>2df76ddc-65c1-4909-0c72-20df84aa8649</td><td>2020-03-23</td><td>UnitedHealthcare</td><td>1186.78</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>16</td><td>2020</td><td>medium</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-cdc6-398cfd52c2ba</td><td>2024-02-11</td><td>Blue Cross Blue Shield</td><td>2673.95</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>17</td><td>2024</td><td>medium</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-9191-7a1d3d06bdb5</td><td>2019-08-25</td><td>UnitedHealthcare</td><td>272.8</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>9</td><td>2019</td><td>low</td></tr><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-bc48-0700e7c47431</td><td>2021-03-08</td><td>Medicare</td><td>85.55</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td><td>2021</td><td>low</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-453b-6e03355cb0d3</td><td>2017-05-28</td><td>Blue Cross Blue Shield</td><td>2673.95</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td><td>2017</td><td>medium</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-1b42-66fa4e109cf2</td><td>2018-05-01</td><td>Blue Cross Blue Shield</td><td>85.55</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td><td>2018</td><td>low</td></tr></tbody>< ...

# %% [markdown]
# 🥇 8. Esquema Gold: Filtrar los datos
#
#
# Tomamos la tabla `consolidated` del esquema `silver` y filtramos solo lo necesario para nuestro reporte final.

# %%
df_consolidated_2021_2025 = spark.read.table("lab_1.silver.consolidated")\
    .filter(col("year").isin(["2021", "2022", "2023", "2024", "2025"]))

df_consolidated_2021_2025.write\
.mode("overwrite")\
.saveAsTable("lab_1.gold.consolidated_2021_2025")

display(df_consolidated_2021_2025.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patientId</th><th>birthdate</th><th>SSN</th><th>first_name</th><th>last_name</th><th>sex</th><th>appointmentId</th><th>appointment_date</th><th>insurance</th><th>appointment_cost</th><th>locationId</th><th>city</th><th>state</th><th>county</th><th>age</th><th>year</th><th>appointment_cost_tier</th></tr></thead><tbody><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-6058-643a3e3427b9</td><td>2022-05-04</td><td>UnitedHealthcare</td><td>1032.5</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td><td>2022</td><td>medium</td></tr><tr><td>43f41797-8919-badf-a707-cd0b07b4f21a</td><td>2008-03-09</td><td>999-93-3802</td><td>Emile522</td><td>Cole117</td><td>M</td><td>43f41797-8919-badf-cdc6-398cfd52c2ba</td><td>2024-02-11</td><td>Blue Cross Blue Shield</td><td>2673.95</td><td>5</td><td>Millbury</td><td>Massachusetts</td><td>Worcester County</td><td>17</td><td>2024</td><td>medium</td></tr><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-bc48-0700e7c47431</td><td>2021-03-08</td><td>Medicare</td><td>85.55</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td><td>2021</td><td>low</td></tr><tr><td>7e186c87-e130-61e6-8039-32e7cf38ffa1</td><td>1992-08-06</td><td>999-15-4812</td><td>Clifton91</td><td>Huel628</td><td>M</td><td>7e186c87-e130-61e6-8094-01989de969aa</td><td>2023-06-01</td><td>Anthem</td><td>85.55</td><td>2</td><td>Boston</td><td>Massachusetts</td><td>Suffolk County</td><td>33</td><td>2023</td><td>low</td></tr><tr><td>d50cec93-0eb0-fed0-bd3c-517fe8b300f5</td><td>2000-03-26</td><td>999-24-1593</td><td>Jordan900</td><td>Jenkins714</td><td>M</td><td>d50cec93-0eb0-fed0-2e6c-6b5a86079f29</td><td>2022-05-29</td><td>Blue Cross Blue Shield</td><td>1402.48</td><td>9</td><td>Taunton</td><td>Massachusetts</td><td>Bristol County</td><td>25</td><td>2022</td><td>medium</td></tr><tr><td>7adc915c-192a-d800-96e1-776559c15965</td><td>2021-11-24</td><td>999-89-6655</td><td>Loreen513</td><td>DuBuque211</td><td>F</td><td>7adc915c-192a-d800-cb9f-320274837a60</td><td>2024-05-01</td><td>UnitedHealthcare</td><td>272.8</td><td>4</td><td>Lowell</td><td>Massachusetts</td><td>Middlesex County</td><td>4</td><td>2024</td><td>low</td></tr><tr><td>74d8e8e3-340d-5dec-3234-54a2a5db23a8</td><td>2016-09-18</td><td>999-63-1426</td><td>Dani520</td><td>Wolff180</td><td>F</td><td>74d8e8e3-340d-5dec-b24c-0f5e6209918a</td><td>2025-09-28</td><td>UnitedHealthcare</td><td>3105.35</td><td>3</td><td>Billerica</td><td>Massachusetts</td><td>Middlesex County</td><td>9</td><td>2025</td><td>high</td></tr><tr><td>70c2211c-b7b7-d0fc-fde6-2ba739867866</td><td>2013-09-22</td><td>999-86-1907</td><td>Babette571</td><td>Hodkiewicz467</td><td>F</td><td>70c2211c-b7b7-d0fc-226f-99664c15d535</td><td>2024-10-07</td><td>Medicare</td><td>1607.58</td><td>1</td><td>Swampscott</td><td>Massachusetts</td><td>Essex County</td><td>12</td><td>2024</td><td>medium</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-e1f4-b2b899dfb846</td><td>2024-06-21</td><td>Anthem</td><td>85.55</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>19</td><td>2024</td><td>low</td></tr><tr><td>40f9a979-11c1-84fe-f3e4-f7e95a19c9d2</td><td>2006-05-17</td><td>999-27-5118</td><td>Moses679</td><td>Volkman526</td><td>M</td><td>40f9a979-11c1-84fe-9296-cc490cd4d3d0</td><td>2024-06-27</td><td>Anthem</td><td>573.98</td><td>8</td><td>Westfield</td><td>Massachusetts</td><td>Hampden County</td><td>19</td><td>2024</td><td>medium</td></tr></tbody></table></div>

# %% [markdown]
# 🥇 9. Esquema Gold: Compartir Tabla a Power BI
# 1. Conectamos la tabla final del esquema `gold` hacia Power BI utilizando **SQL Warehouse** para crear nuestro dashboard.
